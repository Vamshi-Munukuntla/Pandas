# %%
import numpy as np
import pandas as pd

# %%
titanic = pd.read_csv("titanic.csv")
df = pd.read_csv("titanic.csv")

# %%
df.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked deck
# 0         0       3    male  22.0      1      0   7.2500        S  NaN
# 1         1       1  female  38.0      1      0  71.2833        C    C
# 2         1       3  female  26.0      0      0   7.9250        S  NaN
# 3         1       1  female  35.0      1      0  53.1000        S    C
# 4         0       3    male  35.0      0      0   8.0500        S  NaN

# %%
df.tail()
# Out:
#      survived  pclass     sex   age  sibsp  parch   fare embarked deck
# 886         0       2    male  27.0      0      0  13.00        S  NaN
# 887         1       1  female  19.0      0      0  30.00        S    B
# 888         0       3  female   NaN      1      2  23.45        S  NaN
# 889         1       1    male  26.0      0      0  30.00        C    C
# 890         0       3    male  32.0      0      0   7.75        Q  NaN

# %%
pd.options.display.max_rows
# Out:
# 60

# %%
pd.options.display.min_rows
# Out:
# 10

# %% [markdown]
# ## **First Data Inspection**

# %%
df
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked deck
# 0           0       3    male  22.0      1      0   7.2500        S  NaN
# 1           1       1  female  38.0      1      0  71.2833        C    C
# 2           1       3  female  26.0      0      0   7.9250        S  NaN
# 3           1       1  female  35.0      1      0  53.1000        S    C
# 4           0       3    male  35.0      0      0   8.0500        S  NaN
# ..        ...     ...     ...   ...    ...    ...      ...      ...  ...
# 886         0       2    male  27.0      0      0  13.0000        S  NaN
# 887         1       1  female  19.0      0      0  30.0000        S    B
# 888         0       3  female   NaN      1      2  23.4500        S  NaN
# 889         1       1    male  26.0      0      0  30.0000        C    C
# 890         0       3    male  32.0      0      0   7.7500        Q  NaN
#
# [891 rows x 9 columns]

# %%
df.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked deck
# 0         0       3    male  22.0      1      0   7.2500        S  NaN
# 1         1       1  female  38.0      1      0  71.2833        C    C
# 2         1       3  female  26.0      0      0   7.9250        S  NaN
# 3         1       1  female  35.0      1      0  53.1000        S    C
# 4         0       3    male  35.0      0      0   8.0500        S  NaN

# %%
df.tail()
# Out:
#      survived  pclass     sex   age  sibsp  parch   fare embarked deck
# 886         0       2    male  27.0      0      0  13.00        S  NaN
# 887         1       1  female  19.0      0      0  30.00        S    B
# 888         0       3  female   NaN      1      2  23.45        S  NaN
# 889         1       1    male  26.0      0      0  30.00        C    C
# 890         0       3    male  32.0      0      0   7.75        Q  NaN

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 9 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   survived  891 non-null    int64
#  1   pclass    891 non-null    int64
#  2   sex       891 non-null    object
#  3   age       714 non-null    float64
#  4   sibsp     891 non-null    int64
#  5   parch     891 non-null    int64
#  6   fare      891 non-null    float64
#  7   embarked  889 non-null    object
#  8   deck      203 non-null    object
# dtypes: float64(2), int64(4), object(3)
# memory usage: 62.8+ KB

# %%
df.describe()
# Out:
#          survived      pclass         age       sibsp       parch        fare
# count  891.000000  891.000000  714.000000  891.000000  891.000000  891.000000
# mean     0.383838    2.308642   29.699118    0.523008    0.381594   32.204208
# std      0.486592    0.836071   14.526497    1.102743    0.806057   49.693429
# min      0.000000    1.000000    0.420000    0.000000    0.000000    0.000000
# 25%      0.000000    2.000000   20.125000    0.000000    0.000000    7.910400
# 50%      0.000000    3.000000   28.000000    0.000000    0.000000   14.454200
# 75%      1.000000    3.000000   38.000000    1.000000    0.000000   31.000000
# max      1.000000    3.000000   80.000000    8.000000    6.000000  512.329200

# %%
df.describe()
# Out:
#          survived      pclass         age       sibsp       parch        fare
# count  891.000000  891.000000  714.000000  891.000000  891.000000  891.000000
# mean     0.383838    2.308642   29.699118    0.523008    0.381594   32.204208
# std      0.486592    0.836071   14.526497    1.102743    0.806057   49.693429
# min      0.000000    1.000000    0.420000    0.000000    0.000000    0.000000
# 25%      0.000000    2.000000   20.125000    0.000000    0.000000    7.910400
# 50%      0.000000    3.000000   28.000000    0.000000    0.000000   14.454200
# 75%      1.000000    3.000000   38.000000    1.000000    0.000000   31.000000
# max      1.000000    3.000000   80.000000    8.000000    6.000000  512.329200

# %%
df.describe(include=[object])
# Out:
#          sex embarked deck
# count    891      889  203
# unique     2        3    7
# top     male        S    C
# freq     577      644   59

# %%
df.describe(exclude=[np.number])
# Out:
#          sex embarked deck
# count    891      889  203
# unique     2        3    7
# top     male        S    C
# freq     577      644   59

# %%
df.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked deck
# 0         0       3    male  22.0      1      0   7.2500        S  NaN
# 1         1       1  female  38.0      1      0  71.2833        C    C
# 2         1       3  female  26.0      0      0   7.9250        S  NaN
# 3         1       1  female  35.0      1      0  53.1000        S    C
# 4         0       3    male  35.0      0      0   8.0500        S  NaN

# %% [markdown]
# **Categorical**
# - survived  - nominal
# - pclass - Ordinal
# - sex- nominal
# - embarked - nominal
# - deck - nominal
#
# **Numerical**
# - age - Continuous
# - sibsp - discrete
# - parch - discrete
# - fare - continuous

# %%
df.sibsp.value_counts()
# Out:
# sibsp
# 0    608
# 1    209
# 2     28
# 4     18
# 3     16
# 8      7
# 5      5
# Name: count, dtype: int64

# %%
df.describe(include="O")
# Out:
#          sex embarked deck
# count    891      889  203
# unique     2        3    7
# top     male        S    C
# freq     577      644   59

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
len(df)
# Out:
# 891

# %%
df
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked deck
# 0           0       3    male  22.0      1      0   7.2500        S  NaN
# 1           1       1  female  38.0      1      0  71.2833        C    C
# 2           1       3  female  26.0      0      0   7.9250        S  NaN
# 3           1       1  female  35.0      1      0  53.1000        S    C
# 4           0       3    male  35.0      0      0   8.0500        S  NaN
# ..        ...     ...     ...   ...    ...    ...      ...      ...  ...
# 886         0       2    male  27.0      0      0  13.0000        S  NaN
# 887         1       1  female  19.0      0      0  30.0000        S    B
# 888         0       3  female   NaN      1      2  23.4500        S  NaN
# 889         1       1    male  26.0      0      0  30.0000        C    C
# 890         0       3    male  32.0      0      0   7.7500        Q  NaN
#
# [891 rows x 9 columns]

# %%
min(df)
# Out:
# 'age'

# %%
max(df)
# Out:
# 'survived'

# %% [markdown]
# ## DataFrame Attributes

# %%
titanic.shape
# Out:
# (891, 9)

# %%
titanic.size
# Out:
# 8019

# %%
titanic.index
# Out:
# RangeIndex(start=0, stop=891, step=1)

# %%
titanic.columns
# Out:
# Index(['survived', 'pclass', 'sex', 'age', 'sibsp', 'parch', 'fare',
#        'embarked', 'deck'],
#       dtype='object')

# %% [markdown]
# ## DataFrame Methods

# %%
df.head(10)
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked deck
# 0         0       3    male  22.0      1      0   7.2500        S  NaN
# 1         1       1  female  38.0      1      0  71.2833        C    C
# 2         1       3  female  26.0      0      0   7.9250        S  NaN
# 3         1       1  female  35.0      1      0  53.1000        S    C
# 4         0       3    male  35.0      0      0   8.0500        S  NaN
# 5         0       3    male   NaN      0      0   8.4583        Q  NaN
# 6         0       1    male  54.0      0      0  51.8625        S    E
# 7         0       3    male   2.0      3      1  21.0750        S  NaN
# 8         1       3  female  27.0      0      2  11.1333        S  NaN
# 9         1       2  female  14.0      1      0  30.0708        C  NaN

# %%
titanic.describe()
# Out:
#          survived      pclass         age       sibsp       parch        fare
# count  891.000000  891.000000  714.000000  891.000000  891.000000  891.000000
# mean     0.383838    2.308642   29.699118    0.523008    0.381594   32.204208
# std      0.486592    0.836071   14.526497    1.102743    0.806057   49.693429
# min      0.000000    1.000000    0.420000    0.000000    0.000000    0.000000
# 25%      0.000000    2.000000   20.125000    0.000000    0.000000    7.910400
# 50%      0.000000    3.000000   28.000000    0.000000    0.000000   14.454200
# 75%      1.000000    3.000000   38.000000    1.000000    0.000000   31.000000
# max      1.000000    3.000000   80.000000    8.000000    6.000000  512.329200

# %%
df.mean(numeric_only=True)
# Out:
# survived     0.383838
# pclass       2.308642
# age         29.699118
# sibsp        0.523008
# parch        0.381594
# fare        32.204208
# dtype: float64

# %% [markdown]
# ## Method Chaining

# %%
df.mean(numeric_only=True).sort_values().head(2)
# Out:
# parch       0.381594
# survived    0.383838
# dtype: float64

# %%
df.min(numeric_only=True)
# Out:
# survived    0.00
# pclass      1.00
# age         0.42
# sibsp       0.00
# parch       0.00
# fare        0.00
# dtype: float64

# %%
df.sort_values(by='age', ascending=False)
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked deck
# 630         1       1    male  80.0      0      0  30.0000        S    A
# 851         0       3    male  74.0      0      0   7.7750        S  NaN
# 493         0       1    male  71.0      0      0  49.5042        C  NaN
# 96          0       1    male  71.0      0      0  34.6542        C    A
# 116         0       3    male  70.5      0      0   7.7500        Q  NaN
# ..        ...     ...     ...   ...    ...    ...      ...      ...  ...
# 859         0       3    male   NaN      0      0   7.2292        C  NaN
# 863         0       3  female   NaN      8      2  69.5500        S  NaN
# 868         0       3    male   NaN      0      0   9.5000        S  NaN
# 878         0       3    male   NaN      0      0   7.8958        S  NaN
# 888         0       3  female   NaN      1      2  23.4500        S  NaN
#
# [891 rows x 9 columns]

# %% [markdown]
# ## Selecting Columns

# %%
titanic['age']
# Out:
# 0      22.0
# 1      38.0
# 2      26.0
# 3      35.0
# 4      35.0
#        ...
# 886    27.0
# 887    19.0
# 888     NaN
# 889    26.0
# 890    32.0
# Name: age, Length: 891, dtype: float64

# %%
type(titanic['age'])
# Out:
# pandas.core.series.Series

# %%
titanic[['age', 'sex']]
# Out:
#       age     sex
# 0    22.0    male
# 1    38.0  female
# 2    26.0  female
# 3    35.0  female
# 4    35.0    male
# ..    ...     ...
# 886  27.0    male
# 887  19.0  female
# 888   NaN  female
# 889  26.0    male
# 890  32.0    male
#
# [891 rows x 2 columns]

# %%
type(titanic[['age', 'sex']])
# Out:
# pandas.core.frame.DataFrame

# %%
titanic.parch
# Out:
# 0      0
# 1      0
# 2      0
# 3      0
# 4      0
#       ..
# 886    0
# 887    0
# 888    2
# 889    0
# 890    0
# Name: parch, Length: 891, dtype: int64

# %%
titanic.parch.equals(titanic['parch'])
# Out:
# True

# %% [markdown]
# ## Selecting Rows with Position-based Indexing

# %%
summer = pd.read_csv('summer.csv', index_col = "Athlete")

# %%
summer.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 31165 entries, HAJOS, Alfred to LIDBERG, Jimmy
# Data columns (total 8 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Year        31165 non-null  int64
#  1   City        31165 non-null  object
#  2   Sport       31165 non-null  object
#  3   Discipline  31165 non-null  object
#  4   Country     31161 non-null  object
#  5   Gender      31165 non-null  object
#  6   Event       31165 non-null  object
#  7   Medal       31165 non-null  object
# dtypes: int64(1), object(7)
# memory usage: 2.1+ MB

# %%
summer.head()
# Out:
#                     Year    City     Sport Discipline Country Gender  \
# Athlete
# HAJOS, Alfred       1896  Athens  Aquatics   Swimming     HUN    Men
# HERSCHMANN, Otto    1896  Athens  Aquatics   Swimming     AUT    Men
# DRIVAS, Dimitrios   1896  Athens  Aquatics   Swimming     GRE    Men
# MALOKINIS, Ioannis  1896  Athens  Aquatics   Swimming     GRE    Men
# CHASAPIS, Spiridon  1896  Athens  Aquatics   Swimming     GRE    Men
#
#                                          Event   Medal
# Athlete
# HAJOS, Alfred                   100M Freestyle    Gold
# HERSCHMANN, Otto                100M Freestyle  Silver
# DRIVAS, Dimitrios   100M Freestyle For Sailors  Bronze
# MALOKINIS, Ioannis  100M Freestyle For Sailors    Gold
# CHASAPIS, Spiridon  100M Freestyle For Sailors  Silver

# %%
summer.iloc[0]
# Out:
# Year                    1896
# City                  Athens
# Sport               Aquatics
# Discipline          Swimming
# Country                  HUN
# Gender                   Men
# Event         100M Freestyle
# Medal                   Gold
# Name: HAJOS, Alfred, dtype: object

# %%
summer = pd.read_csv('summer.csv')

# %%
summer
# Out:
#        Year    City      Sport           Discipline  \
# 0      1896  Athens   Aquatics             Swimming
# 1      1896  Athens   Aquatics             Swimming
# 2      1896  Athens   Aquatics             Swimming
# 3      1896  Athens   Aquatics             Swimming
# 4      1896  Athens   Aquatics             Swimming
# ...     ...     ...        ...                  ...
# 31160  2012  London  Wrestling  Wrestling Freestyle
# 31161  2012  London  Wrestling  Wrestling Freestyle
# 31162  2012  London  Wrestling  Wrestling Freestyle
# 31163  2012  London  Wrestling  Wrestling Freestyle
# 31164  2012  London  Wrestling  Wrestling Freestyle
#
#                          Athlete Country Gender                       Event  \
# 0                  HAJOS, Alfred     HUN    Men              100M Freestyle
# 1               HERSCHMANN, Otto     AUT    Men              100M Freestyle
# 2              DRIVAS, Dimitrios     GRE    Men  100M Freestyle For Sailors
# ...

# %%
summer.iloc[0]
# Out:
# Year                    1896
# City                  Athens
# Sport               Aquatics
# Discipline          Swimming
# Athlete        HAJOS, Alfred
# Country                  HUN
# Gender                   Men
# Event         100M Freestyle
# Medal                   Gold
# Name: 0, dtype: object

# %%
summer.iloc[2]
# Out:
# Year                                1896
# City                              Athens
# Sport                           Aquatics
# Discipline                      Swimming
# Athlete                DRIVAS, Dimitrios
# Country                              GRE
# Gender                               Men
# Event         100M Freestyle For Sailors
# Medal                             Bronze
# Name: 2, dtype: object

# %%
summer.iloc[-1]
# Out:
# Year                         2012
# City                       London
# Sport                   Wrestling
# Discipline    Wrestling Freestyle
# Athlete            LIDBERG, Jimmy
# Country                       SWE
# Gender                        Men
# Event                    Wg 96 KG
# Medal                      Bronze
# Name: 31164, dtype: object

# %%
summer.iloc[[1,2,3]]
# Out:
#    Year    City     Sport Discipline             Athlete Country Gender  \
# 1  1896  Athens  Aquatics   Swimming    HERSCHMANN, Otto     AUT    Men
# 2  1896  Athens  Aquatics   Swimming   DRIVAS, Dimitrios     GRE    Men
# 3  1896  Athens  Aquatics   Swimming  MALOKINIS, Ioannis     GRE    Men
#
#                         Event   Medal
# 1              100M Freestyle  Silver
# 2  100M Freestyle For Sailors  Bronze
# 3  100M Freestyle For Sailors    Gold

# %%
summer.iloc[1:]
# Out:
#        Year    City      Sport           Discipline  \
# 1      1896  Athens   Aquatics             Swimming
# 2      1896  Athens   Aquatics             Swimming
# 3      1896  Athens   Aquatics             Swimming
# 4      1896  Athens   Aquatics             Swimming
# 5      1896  Athens   Aquatics             Swimming
# ...     ...     ...        ...                  ...
# 31160  2012  London  Wrestling  Wrestling Freestyle
# 31161  2012  London  Wrestling  Wrestling Freestyle
# 31162  2012  London  Wrestling  Wrestling Freestyle
# 31163  2012  London  Wrestling  Wrestling Freestyle
# 31164  2012  London  Wrestling  Wrestling Freestyle
#
#                          Athlete Country Gender                       Event  \
# 1               HERSCHMANN, Otto     AUT    Men              100M Freestyle
# 2              DRIVAS, Dimitrios     GRE    Men  100M Freestyle For Sailors
# 3             MALOKINIS, Ioannis     GRE    Men  100M Freestyle For Sailors
# ...

# %%
summer.iloc[[1,1,1]]
# Out:
#    Year    City     Sport Discipline           Athlete Country Gender  \
# 1  1896  Athens  Aquatics   Swimming  HERSCHMANN, Otto     AUT    Men
# 1  1896  Athens  Aquatics   Swimming  HERSCHMANN, Otto     AUT    Men
# 1  1896  Athens  Aquatics   Swimming  HERSCHMANN, Otto     AUT    Men
#
#             Event   Medal
# 1  100M Freestyle  Silver
# 1  100M Freestyle  Silver
# 1  100M Freestyle  Silver

# %%
summer.iloc[-5:]
# Out:
#        Year    City      Sport           Discipline  \
# 31160  2012  London  Wrestling  Wrestling Freestyle
# 31161  2012  London  Wrestling  Wrestling Freestyle
# 31162  2012  London  Wrestling  Wrestling Freestyle
# 31163  2012  London  Wrestling  Wrestling Freestyle
# 31164  2012  London  Wrestling  Wrestling Freestyle
#
#                          Athlete Country Gender     Event   Medal
# 31160         JANIKOWSKI, Damian     POL    Men  Wg 84 KG  Bronze
# 31161  REZAEI, Ghasem Gholamreza     IRI    Men  Wg 96 KG    Gold
# 31162             TOTROV, Rustam     RUS    Men  Wg 96 KG  Silver
# 31163          ALEKSANYAN, Artur     ARM    Men  Wg 96 KG  Bronze
# 31164             LIDBERG, Jimmy     SWE    Men  Wg 96 KG  Bronze

# %% [markdown]
# ### Slicing Rows & Columns with Position-based Indexing

# %%
summer.head()
# Out:
#    Year    City     Sport Discipline             Athlete Country Gender  \
# 0  1896  Athens  Aquatics   Swimming       HAJOS, Alfred     HUN    Men
# 1  1896  Athens  Aquatics   Swimming    HERSCHMANN, Otto     AUT    Men
# 2  1896  Athens  Aquatics   Swimming   DRIVAS, Dimitrios     GRE    Men
# 3  1896  Athens  Aquatics   Swimming  MALOKINIS, Ioannis     GRE    Men
# 4  1896  Athens  Aquatics   Swimming  CHASAPIS, Spiridon     GRE    Men
#
#                         Event   Medal
# 0              100M Freestyle    Gold
# 1              100M Freestyle  Silver
# 2  100M Freestyle For Sailors  Bronze
# 3  100M Freestyle For Sailors    Gold
# 4  100M Freestyle For Sailors  Silver

# %%
summer.iloc[0]
# Out:
# Year                    1896
# City                  Athens
# Sport               Aquatics
# Discipline          Swimming
# Athlete        HAJOS, Alfred
# Country                  HUN
# Gender                   Men
# Event         100M Freestyle
# Medal                   Gold
# Name: 0, dtype: object

# %%
summer.iloc[0,4]
# Out:
# 'HAJOS, Alfred'

# %%
summer.iloc[0,4:]
# Out:
# Athlete     HAJOS, Alfred
# Country               HUN
# Gender                Men
# Event      100M Freestyle
# Medal                Gold
# Name: 0, dtype: object

# %%
summer.iloc[2, [0,2,4,8]]
# Out:
# Year                    1896
# Sport               Aquatics
# Athlete    DRIVAS, Dimitrios
# Medal                 Bronze
# Name: 2, dtype: object

# %%
summer.iloc[34:39,[1,2,7,8]]
# Out:
#       City      Sport       Event   Medal
# 34  Athens  Athletics   Long Jump  Silver
# 35  Athens  Athletics    Marathon  Bronze
# 36  Athens  Athletics    Marathon    Gold
# 37  Athens  Athletics    Marathon  Silver
# 38  Athens  Athletics  Pole Vault  Bronze

# %%
df.iloc[-10:, [0,1]]
# Out:
#      survived  pclass
# 881         0       3
# 882         0       3
# 883         0       2
# 884         0       3
# 885         0       3
# 886         0       2
# 887         1       1
# 888         0       3
# 889         1       1
# 890         0       3

# %%
df.iloc[2]
# Out:
# survived         1
# pclass           3
# sex         female
# age           26.0
# sibsp            0
# parch            0
# fare         7.925
# embarked         S
# deck           NaN
# Name: 2, dtype: object

# %% [markdown]
# ## Label Based Indexing

# %%
summer.index = summer.Athlete

# %%
summer.loc['DRIVAS, Dimitrios']
# Out:
# Year                                1896
# City                              Athens
# Sport                           Aquatics
# Discipline                      Swimming
# Athlete                DRIVAS, Dimitrios
# Country                              GRE
# Gender                               Men
# Event         100M Freestyle For Sailors
# Medal                             Bronze
# Name: DRIVAS, Dimitrios, dtype: object

# %%
summer.loc['PHELPS, Michael']
# Out:
#                  Year     City     Sport Discipline          Athlete Country  \
# Athlete
# PHELPS, Michael  2004   Athens  Aquatics   Swimming  PHELPS, Michael     USA
# PHELPS, Michael  2004   Athens  Aquatics   Swimming  PHELPS, Michael     USA
# PHELPS, Michael  2004   Athens  Aquatics   Swimming  PHELPS, Michael     USA
# PHELPS, Michael  2004   Athens  Aquatics   Swimming  PHELPS, Michael     USA
# PHELPS, Michael  2004   Athens  Aquatics   Swimming  PHELPS, Michael     USA
# PHELPS, Michael  2004   Athens  Aquatics   Swimming  PHELPS, Michael     USA
# PHELPS, Michael  2004   Athens  Aquatics   Swimming  PHELPS, Michael     USA
# PHELPS, Michael  2004   Athens  Aquatics   Swimming  PHELPS, Michael     USA
# PHELPS, Michael  2008  Beijing  Aquatics   Swimming  PHELPS, Michael     USA
# PHELPS, Michael  2008  Beijing  Aquatics   Swimming  PHELPS, Michael     USA
# PHELPS, Michael  2008  Beijing  Aquatics   Swimming  PHELPS, Michael     USA
# ...

# %%
summer.loc[["PHELPS, Michael", "LEWIS, Carl"], ["Medal", "Event"]]
# Out:
#                   Medal                   Event
# Athlete
# PHELPS, Michael    Gold          100M Butterfly
# PHELPS, Michael    Gold          200M Butterfly
# PHELPS, Michael  Bronze          200M Freestyle
# PHELPS, Michael    Gold  200M Individual Medley
# PHELPS, Michael    Gold  400M Individual Medley
# PHELPS, Michael  Bronze  4X100M Freestyle Relay
# PHELPS, Michael    Gold     4X100M Medley Relay
# PHELPS, Michael    Gold  4X200M Freestyle Relay
# PHELPS, Michael    Gold          100M Butterfly
# PHELPS, Michael    Gold          200M Butterfly
# PHELPS, Michael    Gold          200M Freestyle
# PHELPS, Michael    Gold  200M Individual Medley
# PHELPS, Michael    Gold  400M Individual Medley
# PHELPS, Michael    Gold  4X100M Freestyle Relay
# PHELPS, Michael    Gold     4X100M Medley Relay
# PHELPS, Michael    Gold  4X200M Freestyle Relay
# PHELPS, Michael    Gold          100M Butterfly
# PHELPS, Michael  Silver          200M Butterfly
# ...

# %%
summer.head()
# Out:
#                     Year    City     Sport Discipline             Athlete  \
# Athlete
# HAJOS, Alfred       1896  Athens  Aquatics   Swimming       HAJOS, Alfred
# HERSCHMANN, Otto    1896  Athens  Aquatics   Swimming    HERSCHMANN, Otto
# DRIVAS, Dimitrios   1896  Athens  Aquatics   Swimming   DRIVAS, Dimitrios
# MALOKINIS, Ioannis  1896  Athens  Aquatics   Swimming  MALOKINIS, Ioannis
# CHASAPIS, Spiridon  1896  Athens  Aquatics   Swimming  CHASAPIS, Spiridon
#
#                    Country Gender                       Event   Medal
# Athlete
# HAJOS, Alfred          HUN    Men              100M Freestyle    Gold
# HERSCHMANN, Otto       AUT    Men              100M Freestyle  Silver
# DRIVAS, Dimitrios      GRE    Men  100M Freestyle For Sailors  Bronze
# MALOKINIS, Ioannis     GRE    Men  100M Freestyle For Sailors    Gold
# CHASAPIS, Spiridon     GRE    Men  100M Freestyle For Sailors  Silver

# %%
summer.loc[:"CHASAPIS, Spiridon"]
# Out:
#                     Year    City     Sport Discipline             Athlete  \
# Athlete
# HAJOS, Alfred       1896  Athens  Aquatics   Swimming       HAJOS, Alfred
# HERSCHMANN, Otto    1896  Athens  Aquatics   Swimming    HERSCHMANN, Otto
# DRIVAS, Dimitrios   1896  Athens  Aquatics   Swimming   DRIVAS, Dimitrios
# MALOKINIS, Ioannis  1896  Athens  Aquatics   Swimming  MALOKINIS, Ioannis
# CHASAPIS, Spiridon  1896  Athens  Aquatics   Swimming  CHASAPIS, Spiridon
#
#                    Country Gender                       Event   Medal
# Athlete
# HAJOS, Alfred          HUN    Men              100M Freestyle    Gold
# HERSCHMANN, Otto       AUT    Men              100M Freestyle  Silver
# DRIVAS, Dimitrios      GRE    Men  100M Freestyle For Sailors  Bronze
# MALOKINIS, Ioannis     GRE    Men  100M Freestyle For Sailors    Gold
# CHASAPIS, Spiridon     GRE    Men  100M Freestyle For Sailors  Silver

# %%
# summer.loc[:"PHELPS, Michael"]
# Error: Right Slice Bound

# %%
# summer.loc["PHELPS, Michael":]
# Error: Left Slice Bound

# %%
summer.head(20)
# Out:
#                        Year    City      Sport Discipline  \
# Athlete
# HAJOS, Alfred          1896  Athens   Aquatics   Swimming
# HERSCHMANN, Otto       1896  Athens   Aquatics   Swimming
# DRIVAS, Dimitrios      1896  Athens   Aquatics   Swimming
# MALOKINIS, Ioannis     1896  Athens   Aquatics   Swimming
# CHASAPIS, Spiridon     1896  Athens   Aquatics   Swimming
# CHOROPHAS, Efstathios  1896  Athens   Aquatics   Swimming
# HAJOS, Alfred          1896  Athens   Aquatics   Swimming
# ANDREOU, Joannis       1896  Athens   Aquatics   Swimming
# CHOROPHAS, Efstathios  1896  Athens   Aquatics   Swimming
# NEUMANN, Paul          1896  Athens   Aquatics   Swimming
# PEPANOS, Antonios      1896  Athens   Aquatics   Swimming
# LANE, Francis          1896  Athens  Athletics  Athletics
# SZOKOLYI, Alajos       1896  Athens  Athletics  Athletics
# BURKE, Thomas          1896  Athens  Athletics  Athletics
# HOFMANN, Fritz         1896  Athens  Athletics  Athletics
# ...

# %%
summer.loc["DRIVAS, Dimitrios":"BLAKE, Arthur", "City":"Discipline"]
# Out:
#                          City      Sport Discipline
# Athlete
# DRIVAS, Dimitrios      Athens   Aquatics   Swimming
# MALOKINIS, Ioannis     Athens   Aquatics   Swimming
# CHASAPIS, Spiridon     Athens   Aquatics   Swimming
# CHOROPHAS, Efstathios  Athens   Aquatics   Swimming
# HAJOS, Alfred          Athens   Aquatics   Swimming
# ANDREOU, Joannis       Athens   Aquatics   Swimming
# CHOROPHAS, Efstathios  Athens   Aquatics   Swimming
# NEUMANN, Paul          Athens   Aquatics   Swimming
# PEPANOS, Antonios      Athens   Aquatics   Swimming
# LANE, Francis          Athens  Athletics  Athletics
# SZOKOLYI, Alajos       Athens  Athletics  Athletics
# BURKE, Thomas          Athens  Athletics  Athletics
# HOFMANN, Fritz         Athens  Athletics  Athletics
# CURTIS, Thomas         Athens  Athletics  Athletics
# GOULDING, Grantley     Athens  Athletics  Athletics
# LERMUSIAUX, Albin      Athens  Athletics  Athletics
# FLACK, Edwin           Athens  Athletics  Athletics
# ...

# %%
df = pd.read_csv('summer.csv', index_col='Athlete')
df.loc['UNDA, Maider','Event']
# Out:
# 'Wf 72 KG'

# %%
print(df.loc['UNDA, Maider','Event'])
# Out:
# Wf 72 KG

# %%
sliced = df.loc[['PAVIA, Automne',"OCHAL, Glenn"], ['Country','Sport']]
print(sliced)
# Out:
#                Country   Sport
# Athlete
# PAVIA, Automne     FRA    Judo
# OCHAL, Glenn       USA  Rowing
